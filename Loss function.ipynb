# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
weight=np.linspace(-20,20,500)  #weights starting from -20 to 20 with 500 equidistant datapoints

# %%
loss_function= lambda x:(x**2)

# %%
sse=loss_function(weight)

# %%
plt.figure(fig) ()
plt.plot(weight,sse)
plt.show()
